# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_excel("D:\corona-virus-pakistan-dataset-2020_2\COVID_FINAL_DATA.xlsx","TimeSeries_Action_Screen")

# %%
df
# Out:
#                    Date  Cumulative travelers Screened  \
# 0           11-Mar-2020                         873288
# 1           12-Mar-2020                         894256
# 2           13-Mar-2020                         913542
# 3           14-Mar-2020                         933970
# 4           15-Mar-2020                         954646
# 5           16-Mar-2020                         975634
# 6           17-Mar-2020                         995821
# 7           18-Mar-2020                        1015909
# 8           19-Mar-2020                        1033884
# 9           20-Mar-2020                        1049282
# 10          21-Mar-2020                        1063193
# 11          22-Mar-2020                        1077632
# 12          23-Mar-2020                        1089933
# 13          24-Mar-2020                        1102234
# 14          25-Mar-2020                        1102383
# 15          26-Mar-2020                        1102383
# ...

# %%
df.rename(columns={"Cumulative travelers Screened":"Cumulative_travelers_Screened","Suspected at Points of Entry":"Suspected_at_Points_of_Entry","Travelers Screened at Points ofEntry in last 24 hours":"Travelers_Screened_at_Points_of_Entry_in_last_24 _hours"},inplace=True)

# %%
df
# Out:
#                    Date  Cumulative_travelers_Screened  \
# 0           11-Mar-2020                         873288
# 1           12-Mar-2020                         894256
# 2           13-Mar-2020                         913542
# 3           14-Mar-2020                         933970
# 4           15-Mar-2020                         954646
# 5           16-Mar-2020                         975634
# 6           17-Mar-2020                         995821
# 7           18-Mar-2020                        1015909
# 8           19-Mar-2020                        1033884
# 9           20-Mar-2020                        1049282
# 10          21-Mar-2020                        1063193
# 11          22-Mar-2020                        1077632
# 12          23-Mar-2020                        1089933
# 13          24-Mar-2020                        1102234
# 14          25-Mar-2020                        1102383
# 15          26-Mar-2020                        1102383
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Cumulative_travelers_Screened', 'Suspected_at_Points_of_Entry',
#        'Travelers_Screened_at_Points_of_Entry_in_last_24 _hours'],
#       dtype='object')

# %%
df.replace(np.nan,0,inplace=True)

# %%
df
# Out:
#                    Date  Cumulative_travelers_Screened  \
# 0           11-Mar-2020                         873288
# 1           12-Mar-2020                         894256
# 2           13-Mar-2020                         913542
# 3           14-Mar-2020                         933970
# 4           15-Mar-2020                         954646
# 5           16-Mar-2020                         975634
# 6           17-Mar-2020                         995821
# 7           18-Mar-2020                        1015909
# 8           19-Mar-2020                        1033884
# 9           20-Mar-2020                        1049282
# 10          21-Mar-2020                        1063193
# 11          22-Mar-2020                        1077632
# 12          23-Mar-2020                        1089933
# 13          24-Mar-2020                        1102234
# 14          25-Mar-2020                        1102383
# 15          26-Mar-2020                        1102383
# ...

# %%
df['Suspected_at_Points_of_Entry'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: Suspected_at_Points_of_Entry, dtype: bool

# %%
df['Suspected_at_Points_of_Entry'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: Suspected_at_Points_of_Entry, dtype: bool

# %%
df['Travelers_Screened_at_Points_of_Entry_in_last_24 _hours'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: Travelers_Screened_at_Points_of_Entry_in_last_24 _hours, dtype: bool

# %%
df.to_excel("D:\TimeSeries_Action_Screen.xlsx")
